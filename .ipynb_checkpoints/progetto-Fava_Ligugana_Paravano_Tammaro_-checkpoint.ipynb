# %%
import pandas as pd
import numpy as np
import networkx as nx
from pyvis import network as net
from pyvis.network import Network
import random
#from serpapi import GoogleScholarSearch
import json
import requests

# %% [markdown]
# # Creation of DataFarme

# %%
#import given dataframe nodes
nodes = pd.read_csv("Data/nodes.csv")

nodes['author_id'] = None
nodes['cited_by'] = None 
nodes['interests'] = None
nodes.to_csv('Data/nodes.csv', index=False)

edges = pd.DataFrame(columns=['author1','author2']) 
edges.to_csv('Data/edges.csv', index=False)

# %% [markdown]
# ## ES 1
# A partire da nodes.csv, utilizzare la libreria Python SerpAPI per scaricare, per ciascuno dei 7 autori elencati:
# - author_id: ID identificativo del profilo Google Scholar
# - cited_by: numero totale di citazioni ricevute
# - interests: elenco degli interessi di ciascun autore
# Sfruttando la libreria Python Pandas, usare la struttura dati DataFrame per aggiornare il file originale con apposite colonne e memorizzarlo nella cartella /data.

# %%
#dictionary with the keys
listApikey ={
    'SERP_API_KEY_FAVA': "1ae8a37d9b3dabb5732fcd7a9cb57410194766951242a4f4ac5bbd9fb7012048", 
    'SERP_API_KEY_LIGUGNANA': "11a077a8bee5bb1c2a25af914046bc7ce53050b3416e5720239e43223c63374b",
    'SERP_API_KEY_PARAVANO' :  "42b4919fd319f0ff32c19ae31a88b4ff67a544e29ca2a017905088b2ae11e60e",
    'SERP_API_KEY_TAMMARO': "6eaf5a9a0d2eef8bf026a947a3dffbb0d31cb1d6e122b81c0e6062f6b23a4c40"
}

#key in use right now
apikey = "26eb1104ccb6c743b29cf9dbc6e9bf89f8f2cfae60daf9a82c4feb2cc932c52a"

#function to randomise the key in use
'''
def key_choice():
    return random.choice(list(apikey.items()))[1]
'''
# Out:
# '\ndef key_choice():\n    return random.choice(list(apikey.items()))[1]\n'

# %%
#overwrite the row of nodes with df_update in the right position
#if the author given isn't in nodes, then it will get concatenated

def update_nodes(df_update, nodes):
    
    #read nodes csv
    nodesMod = pd.read_csv(r'Data/nodes.csv')

    print('nome: ', df_update["name"][0])

    #check if the author is in nodes using attributre name as parameter
    if (nodes["name"] == df_update["name"][0]).any():
        print('già presente in nodes')
        #if author is already in nodes update the present row with df_update
        for index in range(len(nodes)):
            if nodes["name"][index] == df_update["name"][0]:
                print('sta sovrascrivendo con: ', df_update.iloc[0])
                nodesMod.iloc[index]=df_update.iloc[0]
                nodesMod.to_csv(r'Data/nodes.csv', index=False) #overwrite the csv with the new row
    else:
        #if the author isn't already in nodes we concatenete it
        nodesMod = pd.concat([nodesMod, df_update], ignore_index=True)
        nodesMod.to_csv(r'Data/nodes.csv', index=False) #overwrite the csv by adding df_update at the end

# %%
# author_profile returns a dataframe with name, affiliations, author_id, cited_by, interests of a given author

def author_profile(apiKey, name, affiliation, nodes):

    base_url = "https://serpapi.com/search"

    # search among scholar profiles for the one with the given name
    params = {
        "api_key": apiKey,
        "engine": "google_scholar_profiles",
        "hl": "en",
        "mauthors": name
    }

    # save the request response in json
    response = requests.get(base_url, params=params)
    results = response.json()

    # save the results in a json
    name_json = "json/" + name + ".json"

    with open(name_json, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)

    print(results)

    # scroll through profiles to verifies if the profile found is the one that wa are searching for
    for profile in results["profiles"]:
        interests = ''
        if (affiliation in profile["affiliations"]) and (name in profile["name"]):
            # save the information needed for the right author
            authorId = profile["author_id"]
            citedBy = profile["cited_by"]
            if 'interests' in profile:
                if profile["interests"] != '':
                    interests = ", ".join([i['title'] for i in profile["interests"]])  # select only titles for each interest, join to remove the square brackets (now seen as a single string instead of a list)
            else:
                profile["interests"] = ''

            # create a new row of the dataframe with all the information needed and return it
            df_update = pd.DataFrame({'name': [name],'affiliations': [affiliation],'author_id': [authorId],'cited_by': [citedBy],'interests': [interests]})

            update_nodes(df_update, nodes)

# %%
nodes = pd.read_csv("Data/nodes.csv")

print(author_profile(apikey,"Wolfgang Nejdl" ,"Professor of Computer Science, Leibniz Universität Hannover, L3S Research Center …", nodes))
# Out:
# {'search_metadata': {'id': '6567550937014cca95498a29', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/348534f47eb0b84d/6567550937014cca95498a29.json', 'created_at': '2023-11-29 15:13:13 UTC', 'processed_at': '2023-11-29 15:13:13 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Wolfgang+Nejdl&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/348534f47eb0b84d/6567550937014cca95498a29.html', 'total_time_taken': 0.86}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Wolfgang Nejdl', 'hl': 'en'}, 'profiles': [{'name': 'Wolfgang Nejdl', 'link': 'https://scholar.google.com/citations?hl=en&user=LC62bdYAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=LC62bdYAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'LC62bdYAAAAJ', 'affiliations': 'Professor of Computer Science, Leibniz Universität Hannover, L3S Research Center …', 'email': 'Verified email at kbs.uni-hannover.de', 'cited_by': 25466, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Web Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:web_science'}, {'title': 'Social Media', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asocial_media', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:social_media'}, {'title': 'Data Mining', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_mining', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_mining'}, {'title': 'Semantic Technologies', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_technologies', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_technologies'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=LC62bdYAAAAJ&citpid=3'}]}
# nome:  Wolfgang Nejdl
# già presente in nodes
# sta sovrascrivendo con:  name                                               Wolfgang Nejdl
# affiliations    Professor of Computer Science, Leibniz Univers...
# author_id                                            LC62bdYAAAAJ
# cited_by                                                    25466
# interests                                                    None
# Name: 0, dtype: object
# None

# %%
#nodes_information return a dataframe with name, affiliations, author_id, cited_by, interests;
#for each node in the given dataframe containing name and affiliation for each author 

def nodes_information(apikey, df):
    
    #iterate the row of the given df, for each one makes the call to the author_profile
    for index, row in df.iterrows():
        author_data = author_profile(apikey, row['name'], row['affiliations'])

# %% [markdown]
# ## Main es 1

# %%
#get the final dataframe of the 7 originals authors with name, affiliations, author_id, cited_by, interests 
nodes_information(apikey, nodes)

# %% [markdown]
# ## 2. Analisi dei Coautori tramite SerpAPI su Google Scholar
#
# ### a. Ottenere i Coautori dei 7 Autori Principali
#
# Per ciascuno dei 7 autori, utilizzare il suo ID per accedere al relativo profilo Google Scholar e scaricare l'elenco dei suoi coautori utilizzando SerpAPI. Con tale elenco di nomi:;
#
# #### a.1. Ricerca dei Coautori su Google Scholar
#
# Utilizzare le SerpAPI per cercare su Google Scholar un ricercatore che corrisponde a ciascun nome nella lista di coautori. Per ogni risultato, salvare le informazioni come `name`, `affiliations`, `author_id`, `cited_by`, e `interests` in un nuovo DataFrame contenente tutte queste informazioni relative ai coautori dei 7 autori originari.
#
# ### b. Concatenazione dei DataFrame
#
# Concatenare il DataFrame contenente le informazioni sui 7 autori principali con quello dei coautori generato al punto 2a in un unico DataFrame.
#
# ### c. Creazione del DataFrame delle Relazioni di Co-Authorship
#
# Creare un terzo DataFrame con le colonne `author1` e `author2` che rappresenta le co-authorship. In questo DataFrame, una riga rappresenta un arco di coauthorship tra due autori. La co-authorship è binaria, non pesata.
#
# #### Esempio
#
# Se David La Barbera e Michael Soprano sono coautori, una riga del DataFrame creato al punto 2c rappresenterà questa relazione.
#
# ### Risultati Finali
#
# A questo punto, saranno stati prodotti due DataFrame:
#
# - Uno contenente le informazioni relative agli autori (originali + i relativi coautori), con le colonne `name`, `affiliations`, `cited_by`, `interests`. Salvare come `nodes.csv` nella cartella `/data` tale DataFrame.
#
# - Un altro per le relazioni di co-authorship dai 7 autori principali verso i relativi coautori, con colonne `author1` e `author2`. Salvare come `edges.csv` nella cartella `/data` tale DataFrame.

# %%
def get_profile_coauthors(apiKey, authorID,nodes):
    base_url = "https://serpapi.com/search"

    #search among scholar profiles for the one with the given author_id
    params = {
        "api_key": apiKey,
        "engine": "google_scholar_author",
        "hl": "en",
        "author_id": authorID
    }
    response = requests.get(base_url, params = params)
    results = response.json()
    
    name_json = "json/"+authorID + ".json"
    with open(name_json, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)
    
    #crea solo un dataFrame di appoggio con colonna name e affiliations, secondo me non serve, ammno che non venga usato da qualche aletra parte
    authorName = results["author"]
    edges = pd.read_csv(r'Data/edges.csv')
    #for each coauthor save name and affiliation in a dataframe
    for coautore in results['co_authors']:
        coppie_da_cercare = [(authorName["name"], coautore['name']), (coautore['name'], authorName["name"])]
        #Cicla attraverso il DataFrame e verifica le condizioni
        trovato = True
        for index, row in edges.iterrows():
            if (row['author1'], row['author2']) in coppie_da_cercare or (row['author2'], row['author1']) in coppie_da_cercare:
                #esiste gia un collegamento tra aurtore e coautore o viceversa
                trovato = False
        if(trovato):
            row_edge = pd.DataFrame([{'author1' : authorName["name"], 'author2': coautore['name']}])
            edges = pd.concat([edges, row_edge], ignore_index=True)
        #adding coauthors to nodes

        if 'affiliations' in coautore:
            if coautore['affiliations'] == '':
                print('if ',coautore['affiliations'])
                author_profile(apiKey, coautore['name'], '', nodes)
            else:
                print('else ',coautore['affiliations'])
                author_profile(apiKey, coautore['name'], coautore['affiliations'], nodes)
        else:
            coautore['affiliations'] = ''

    edges.to_csv(r'Data/edges.csv', index=False)

# %%
nodes = pd.read_csv("Data/nodes.csv")

get_profile_coauthors(apikey,'egHDpFkAAAAJ',nodes)
# Out:
# else  Full professor of Computer Science and Information Technology
# {'search_metadata': {'id': '656775840b50626127022c24', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/daba833fba74433e/656775840b50626127022c24.json', 'created_at': '2023-11-29 17:31:48 UTC', 'processed_at': '2023-11-29 17:31:48 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Stefano+Mizzaro&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/daba833fba74433e/656775840b50626127022c24.html', 'total_time_taken': 0.19}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Stefano Mizzaro', 'hl': 'en'}, 'profiles': [{'name': 'Stefano Mizzaro', 'link': 'https://scholar.google.com/citations?hl=en&user=2wvJC6IAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=2wvJC6IAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '2wvJC6IAAAAJ', 'affiliations': 'Full professor of Computer Science and Information Technology', 'email': 'Verified email at uniud.it', 'cited_by': 4742, 'interests': [{'title': 'Information retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'mobile systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amobile_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:mobile_systems'}, {'title': 'scholarly publishing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ascholarly_publishing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:scholarly_publishing'}, {'title': 'crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'misinformation and fake news detection', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amisinformation_and_fake_news_detection', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:misinformation_and_fake_news_detection'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=2wvJC6IAAAAJ&citpid=1'}]}
# nome:  Stefano Mizzaro
# già presente in nodes
# sta sovrascrivendo con:  name                                              Stefano Mizzaro
# affiliations    Full professor of Computer Science and Informa...
# author_id                                            2wvJC6IAAAAJ
# cited_by                                                     4742
# interests       Information retrieval, mobile systems, scholar...
# Name: 0, dtype: object
# else  University of Udine
# {'search_metadata': {'id': '65677585d04d6db9fc89381b', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/94c51138563836a6/65677585d04d6db9fc89381b.json', 'created_at': '2023-11-29 17:31:49 UTC', 'processed_at': '2023-11-29 17:31:49 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Kevin+Roitero&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/94c51138563836a6/65677585d04d6db9fc89381b.html', 'total_time_taken': 0.66}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Kevin Roitero', 'hl': 'en'}, 'profiles': [{'name': 'Kevin Roitero', 'link': 'https://scholar.google.com/citations?hl=en&user=1xd52jMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=1xd52jMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '1xd52jMAAAAJ', 'affiliations': 'University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 691, 'interests': [{'title': 'Artificial Intelligence', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:artificial_intelligence'}, {'title': 'Crowdsourcing and Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing_and_human_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing_and_human_computation'}, {'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=1xd52jMAAAAJ&citpid=6'}]}
# nome:  Kevin Roitero
# già presente in nodes
# sta sovrascrivendo con:  name                                                Kevin Roitero
# affiliations                                  University of Udine
# author_id                                            1xd52jMAAAAJ
# cited_by                                                      691
# interests       Artificial Intelligence, Crowdsourcing and Hum...
# Name: 0, dtype: object
# else  Associate Professor at the University of Queensland
# {'search_metadata': {'id': '656775863c3fb261066ae7b8', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/bee3426795a45964/656775863c3fb261066ae7b8.json', 'created_at': '2023-11-29 17:31:50 UTC', 'processed_at': '2023-11-29 17:31:50 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Gianluca+Demartini&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/bee3426795a45964/656775863c3fb261066ae7b8.html', 'total_time_taken': 1.03}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Gianluca Demartini', 'hl': 'en'}, 'profiles': [{'name': 'Gianluca Demartini', 'link': 'https://scholar.google.com/citations?hl=en&user=PCAiILsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=PCAiILsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'PCAiILsAAAAJ', 'affiliations': 'Associate Professor at the University of Queensland', 'email': 'Verified email at cs.berkeley.edu', 'cited_by': 5355, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}, {'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=PCAiILsAAAAJ&citpid=6'}]}
# nome:  Gianluca Demartini
# già presente in nodes
# sta sovrascrivendo con:  name                                           Gianluca Demartini
# affiliations    Associate Professor at the University of Queen...
# author_id                                            PCAiILsAAAAJ
# cited_by                                                     5355
# interests       Information Retrieval, Semantic Web, Human Com...
# Name: 0, dtype: object
# else  Computer Science Department - University of Rome La Sapienza
# {'search_metadata': {'id': '65677587033e942777d63a84', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/c2816543d3819dfd/65677587033e942777d63a84.json', 'created_at': '2023-11-29 17:31:51 UTC', 'processed_at': '2023-11-29 17:31:51 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Alessandro+Checco&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/c2816543d3819dfd/65677587033e942777d63a84.html', 'total_time_taken': 1.06}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Alessandro Checco', 'hl': 'en'}, 'profiles': [{'name': 'Alessandro Checco', 'link': 'https://scholar.google.com/citations?hl=en&user=crhkrNcAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=crhkrNcAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'crhkrNcAAAAJ', 'affiliations': 'Computer Science Department - University of Rome La Sapienza', 'email': 'Verified email at uniroma1.it', 'cited_by': 904, 'interests': [{'title': 'Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}, {'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'Graph Theory', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Agraph_theory', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:graph_theory'}, {'title': 'Markov Chains', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amarkov_chains', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:markov_chains'}, {'title': 'Wireless Networks', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Awireless_networks', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:wireless_networks'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=crhkrNcAAAAJ&citpid=2'}]}
# nome:  Alessandro Checco
# già presente in nodes
# sta sovrascrivendo con:  name                                            Alessandro Checco
# affiliations    Computer Science Department - University of Ro...
# author_id                                            crhkrNcAAAAJ
# cited_by                                                      904
# interests       Human Computation, Crowdsourcing, Graph Theory...
# Name: 0, dtype: object
# else  Professor of computer science, King's College London, United Kingdom
# {'search_metadata': {'id': '65677589a74fe074e554f18f', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/d251de08272a8bfd/65677589a74fe074e554f18f.json', 'created_at': '2023-11-29 17:31:53 UTC', 'processed_at': '2023-11-29 17:31:53 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Elena+Simperl&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/d251de08272a8bfd/65677589a74fe074e554f18f.html', 'total_time_taken': 1.19}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Elena Simperl', 'hl': 'en'}, 'profiles': [{'name': 'Elena Simperl', 'link': 'https://scholar.google.com/citations?hl=en&user=xB7s3wgAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=xB7s3wgAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'xB7s3wgAAAAJ', 'affiliations': "Professor of computer science, King's College London, United Kingdom", 'email': 'Verified email at kcl.ac.uk', 'cited_by': 7015, 'interests': [{'title': 'knowledge graphs', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aknowledge_graphs', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:knowledge_graphs'}, {'title': 'knowledge engineering', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aknowledge_engineering', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:knowledge_engineering'}, {'title': 'open data', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aopen_data', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:open_data'}, {'title': 'social computing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asocial_computing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:social_computing'}, {'title': 'human computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=xB7s3wgAAAAJ&citpid=3'}]}
# nome:  Elena Simperl
# else  School of Computing Technologies, RMIT University
# {'search_metadata': {'id': '6567758ac56d93d7d7ebe1a4', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/2e2cfd4a31b9bd78/6567758ac56d93d7d7ebe1a4.json', 'created_at': '2023-11-29 17:31:54 UTC', 'processed_at': '2023-11-29 17:31:54 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Falk+Scholer&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/2e2cfd4a31b9bd78/6567758ac56d93d7d7ebe1a4.html', 'total_time_taken': 0.21}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Falk Scholer', 'hl': 'en'}, 'profiles': [{'name': 'Falk Scholer', 'link': 'https://scholar.google.com/citations?hl=en&user=qOLjlqsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=qOLjlqsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'qOLjlqsAAAAJ', 'affiliations': 'School of Computing Technologies, RMIT University', 'email': 'Verified email at rmit.edu.au', 'cited_by': 4650, 'interests': [{'title': 'Information retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'search', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asearch', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:search'}, {'title': '… transparency and ethics of algorithms AI and …', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atransparency_and_ethics_of_algorithms_ai_and', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:fairness_accountability_transparency_and_ethics_of_algorithms_ai_and_computing'}, {'title': 'data science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_science'}, {'title': 'dat', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adat', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:dat'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=qOLjlqsAAAAJ&citpid=2'}, {'name': 'Avner Falk', 'link': 'https://scholar.google.com/citations?hl=en&user=m8TXhSQAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=m8TXhSQAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'm8TXhSQAAAAJ', 'affiliations': 'Independent Scholar', 'cited_by': 679, 'interests': [{'title': 'Psychoanalysis', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Apsychoanalysis', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:psychoanalysis'}, {'title': 'Psychohistory', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Apsychohistory', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:psychohistory'}, {'title': 'Psychobiography', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Apsychobiography', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:psychobiography'}, {'title': 'Political Psychology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Apolitical_psychology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:political_psychology'}, {'title': 'Psychogeography', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Apsychogeography', 'link': 'https://scholar.google.co ...
# nome:  Falk Scholer
# già presente in nodes
# sta sovrascrivendo con:  name                                                 Falk Scholer
# affiliations    School of Computing Technologies, RMIT University
# author_id                                            qOLjlqsAAAAJ
# cited_by                                                     4650
# interests       Information retrieval, search, … transparency ...
# Name: 0, dtype: object
# else  The University of Queensland
# {'search_metadata': {'id': '6567758bf218019411f94527', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/6ecd72e5110db95c/6567758bf218019411f94527.json', 'created_at': '2023-11-29 17:31:55 UTC', 'processed_at': '2023-11-29 17:31:55 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Lei+Han&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/6ecd72e5110db95c/6567758bf218019411f94527.html', 'total_time_taken': 0.36}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Lei Han', 'hl': 'en'}, 'profiles': [{'name': 'Leihan Tang', 'link': 'https://scholar.google.com/citations?hl=en&user=kYTmdEMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=kYTmdEMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'kYTmdEMAAAAJ', 'affiliations': 'Professor of Physics, Hong Kong Baptist University', 'email': 'Verified email at hkbu.edu.hk', 'cited_by': 6655, 'interests': [{'title': 'Statistical Physics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Astatistical_physics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:statistical_physics'}, {'title': 'Biological Physics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abiological_physics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:biological_physics'}, {'title': 'Computational Physics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acomputational_physics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:computational_physics'}, {'title': 'Systems Biology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asystems_biology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:systems_biology'}, {'title': 'Quantitative Modeling', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aquantitative_modeling', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:quantitative_modeling'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=kYTmdEMAAAAJ&citpid=4'}, {'name': 'Lei Han', 'link': 'https://scholar.google.com/citations?hl=en&user=Tz4_zi8AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=Tz4_zi8AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'Tz4_zi8AAAAJ', 'affiliations': 'Tencent Robotics X & Tencent AI Lab', 'email': 'Verified email at tencent.com', 'cited_by': 1755, 'interests': [{'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Tz4_zi8AAAAJ&citpid=3'}, {'name': 'Xiang-Lei Han（韩相磊）', 'link': 'https://scholar.google.com/citations?hl=en&user=VYsX2n0AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=VYsX2n0AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'VYsX2n0AAAAJ', 'affiliations': '', 'cited_by': 660, 'interests': [{'title': 'Nanofabrication', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ananofabrication', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:nanofabrication'}, {'title': 'Nanoelectronics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ananoelectronics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:nanoelectronics'}, {'title': ...
# nome:  Lei Han
# già presente in nodes
# sta sovrascrivendo con:  name                                 Lei Han
# affiliations    The University of Queensland
# author_id                       Oibami4AAAAJ
# cited_by                                 230
# interests
# Name: 0, dtype: object
# else  Lions Eye Institute and Curtin University
# {'search_metadata': {'id': '6567758cd737d7a9dd059b59', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/dd7f42f1ab4a1f1b/6567758cd737d7a9dd059b59.json', 'created_at': '2023-11-29 17:31:56 UTC', 'processed_at': '2023-11-29 17:31:56 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Andrew+Turpin&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/dd7f42f1ab4a1f1b/6567758cd737d7a9dd059b59.html', 'total_time_taken': 0.25}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Andrew Turpin', 'hl': 'en'}, 'profiles': [{'name': 'Andrew Turpin', 'link': 'https://scholar.google.com/citations?hl=en&user=lCZblDwAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=lCZblDwAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'lCZblDwAAAAJ', 'affiliations': 'Lions Eye Institute and Curtin University', 'email': 'Verified email at curtin.edu.au', 'cited_by': 6893, 'interests': [{'title': 'Human vision', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_vision', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_vision'}, {'title': 'Computer vision', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acomputer_vision', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:computer_vision'}, {'title': 'Information Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_science'}, {'title': 'Data Analysis', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_analysis', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_analysis'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=lCZblDwAAAAJ&citpid=4'}]}
# nome:  Andrew Turpin
# già presente in nodes
# sta sovrascrivendo con:  name                                                Andrew Turpin
# affiliations            Lions Eye Institute and Curtin University
# author_id                                            lCZblDwAAAAJ
# cited_by                                                     6893
# interests       Human vision, Computer vision, Information Sci...
# Name: 0, dtype: object
# else  Assistant Professor, Web Information Systems, Delft University of Technology
# {'search_metadata': {'id': '6567758df26ac65a95b1bc81', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/9c8a55b9b9719035/6567758df26ac65a95b1bc81.json', 'created_at': '2023-11-29 17:31:57 UTC', 'processed_at': '2023-11-29 17:31:57 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Ujwal+Gadiraju&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/9c8a55b9b9719035/6567758df26ac65a95b1bc81.html', 'total_time_taken': 1.17}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Ujwal Gadiraju', 'hl': 'en'}, 'profiles': [{'name': 'Ujwal Gadiraju', 'link': 'https://scholar.google.com/citations?hl=en&user=FX7BF6QAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=FX7BF6QAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'FX7BF6QAAAAJ', 'affiliations': 'Assistant Professor, Web Information Systems, Delft University of Technology', 'email': 'Verified email at tudelft.nl', 'cited_by': 3267, 'interests': [{'title': 'Human-centered AI', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_centered_ai', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_centered_ai'}, {'title': 'Crowd Computing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowd_computing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowd_computing'}, {'title': 'Human-Computer Interaction', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computer_interaction', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computer_interaction'}, {'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Conversational Interfaces', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aconversational_interfaces', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:conversational_interfaces'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=FX7BF6QAAAAJ&citpid=20'}]}
# nome:  Ujwal Gadiraju
# già presente in nodes
# sta sovrascrivendo con:  name                                               Ujwal Gadiraju
# affiliations    Assistant Professor, Web Information Systems, ...
# author_id                                            FX7BF6QAAAAJ
# cited_by                                                     3267
# interests       Human-centered AI, Crowd Computing, Human-Comp...
# Name: 0, dtype: object
# else  University of Zurich
# {'search_metadata': {'id': '6567758ef55d77e73f1a245e', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/a6321e9be9974aaf/6567758ef55d77e73f1a245e.json', 'created_at': '2023-11-29 17:31:58 UTC', 'processed_at': '2023-11-29 17:31:59 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Cristina+Sarasua&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/a6321e9be9974aaf/6567758ef55d77e73f1a245e.html', 'total_time_taken': 0.37}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Cristina Sarasua', 'hl': 'en'}, 'profiles': [{'name': 'Cristina Sarasua', 'link': 'https://scholar.google.com/citations?hl=en&user=i_2lvZwAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=i_2lvZwAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'i_2lvZwAAAAJ', 'affiliations': 'University of Zurich', 'email': 'Verified email at ifi.uzh.ch', 'cited_by': 769, 'interests': [{'title': 'CSCW', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acscw', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:cscw'}, {'title': 'Digital Democracy', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adigital_democracy', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:digital_democracy'}, {'title': 'Civic Technology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acivic_technology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:civic_technology'}, {'title': 'Data Analytics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_analytics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_analytics'}, {'title': 'Knowledge Graphs', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aknowledge_graphs', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:knowledge_graphs'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}]}
# nome:  Cristina Sarasua
# else  University of Southampton
# {'search_metadata': {'id': '6567758fe815af8497016c5a', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/654e8a5f57f5e336/6567758fe815af8497016c5a.json', 'created_at': '2023-11-29 17:31:59 UTC', 'processed_at': '2023-11-29 17:31:59 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Luis-Daniel+Ib%C3%A1%C3%B1ez&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/654e8a5f57f5e336/6567758fe815af8497016c5a.html', 'total_time_taken': 0.83}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Luis-Daniel Ibáñez', 'hl': 'en'}, 'profiles': [{'name': 'Luis-Daniel Ibáñez', 'link': 'https://scholar.google.com/citations?hl=en&user=Vf-AkkUAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=Vf-AkkUAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'Vf-AkkUAAAAJ', 'affiliations': 'University of Southampton', 'email': 'Verified email at soton.ac.uk', 'cited_by': 692, 'interests': [{'title': 'Linked Data', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Alinked_data', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:linked_data'}, {'title': 'Collaborative Systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acollaborative_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:collaborative_systems'}, {'title': 'Optimistic Replication', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aoptimistic_replication', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:optimistic_replication'}, {'title': 'Provenance Semirings', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprovenance_semirings', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:provenance_semirings'}, {'title': 'Update Exchange', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aupdate_exchange', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:update_exchange'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Vf-AkkUAAAAJ&citpid=3'}]}
# nome:  Luis-Daniel Ibáñez
# else  Associate Professor of Medical Informatics, University of Udine
# {'search_metadata': {'id': '65677591116a55225ee89ea0', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/2b22b4d4cfec7e24/65677591116a55225ee89ea0.json', 'created_at': '2023-11-29 17:32:01 UTC', 'processed_at': '2023-11-29 17:32:01 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Vincenzo+Della+Mea&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/2b22b4d4cfec7e24/65677591116a55225ee89ea0.html', 'total_time_taken': 0.99}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Vincenzo Della Mea', 'hl': 'en'}, 'profiles': [{'name': 'Vincenzo Della Mea', 'link': 'https://scholar.google.com/citations?hl=en&user=BF3B4KAAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=BF3B4KAAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'BF3B4KAAAAAJ', 'affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 2892, 'interests': [{'title': 'medical informatics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amedical_informatics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:medical_informatics'}, {'title': 'telemedicine', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atelemedicine', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:telemedicine'}, {'title': 'digital pathology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adigital_pathology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:digital_pathology'}, {'title': 'biomedical classifications and ontologies', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abiomedical_classifications_and_ontologies', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:biomedical_classifications_and_ontologies'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=BF3B4KAAAAAJ&citpid=7'}]}
# nome:  Vincenzo Della Mea
# già presente in nodes
# sta sovrascrivendo con:  name                                           Vincenzo Della Mea
# affiliations    Associate Professor of Medical Informatics, Un...
# author_id                                            BF3B4KAAAAAJ
# cited_by                                                     2892
# interests       medical informatics, telemedicine, digital pat...
# Name: 0, dtype: object
# else  Amazon
# {'search_metadata': {'id': '65677592660dbdd6fac1ccf0', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/4abe569989b34a18/65677592660dbdd6fac1ccf0.json', 'created_at': '2023-11-29 17:32:02 UTC', 'processed_at': '2023-11-29 17:32:02 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Marco+Basaldella&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/4abe569989b34a18/65677592660dbdd6fac1ccf0.html', 'total_time_taken': 1.15}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Marco Basaldella', 'hl': 'en'}, 'profiles': [{'name': 'Marco Basaldella', 'link': 'https://scholar.google.com/citations?hl=en&user=SRvx2QoAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=SRvx2QoAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'SRvx2QoAAAAJ', 'affiliations': 'Amazon', 'email': 'Verified email at amazon.co.uk', 'cited_by': 519, 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}]}
# nome:  Marco Basaldella
# else  Databricks, TomTom, IBM Research, University of Trento, Create-net
# {'search_metadata': {'id': '65677594e0ded49f1f559180', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/75b418088d9c89eb/65677594e0ded49f1f559180.json', 'created_at': '2023-11-29 17:32:04 UTC', 'processed_at': '2023-11-29 17:32:04 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Mattia+Zeni&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/75b418088d9c89eb/65677594e0ded49f1f559180.html', 'total_time_taken': 0.23}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Mattia Zeni', 'hl': 'en'}, 'profiles': [{'name': 'Mattia Zeni', 'link': 'https://scholar.google.com/citations?hl=en&user=DL18RZEAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=DL18RZEAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'DL18RZEAAAAJ', 'affiliations': 'Databricks, TomTom, IBM Research, University of Trento, Create-net', 'email': 'Verified email at databricks.com', 'cited_by': 610, 'interests': [{'title': 'Big Data', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abig_data', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:big_data'}, {'title': 'AI', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aai', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:ai'}, {'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}, {'title': 'Human-Centered AI', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_centered_ai', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_centered_ai'}, {'title': 'Privacy-Aware Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprivacy_aware_machine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:privacy_aware_machine_learning'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=DL18RZEAAAAJ&citpid=3'}]}
# nome:  Mattia Zeni
# else  Datamantix
# {'search_metadata': {'id': '65677595d5a531b33279dddd', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/103cecd47db86171/65677595d5a531b33279dddd.json', 'created_at': '2023-11-29 17:32:05 UTC', 'processed_at': '2023-11-29 17:32:05 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Dante+Degl%27Innocenti&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/103cecd47db86171/65677595d5a531b33279dddd.html', 'total_time_taken': 0.81}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': "Dante Degl'Innocenti", 'hl': 'en'}, 'profiles': [{'name': "Dante Degl'Innocenti", 'link': 'https://scholar.google.com/citations?hl=en&user=Ay6L7NsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=Ay6L7NsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'Ay6L7NsAAAAJ', 'affiliations': 'Datamantix', 'email': 'Verified email at spes.uniud.it', 'cited_by': 117, 'interests': [{'title': 'Artificial Intelligence', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:artificial_intelligence'}, {'title': 'Deep Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adeep_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:deep_learning'}, {'title': 'Natural Language Processing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Anatural_language_processing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:natural_language_processing'}, {'title': 'Data Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_science'}, {'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Ay6L7NsAAAAJ&citpid=2'}]}
# nome:  Dante Degl'Innocenti
# else  Huawei Technologies
# {'search_metadata': {'id': '65677596b5961ea5423e7235', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/b6e01c910d434b94/65677596b5961ea5423e7235.json', 'created_at': '2023-11-29 17:32:06 UTC', 'processed_at': '2023-11-29 17:32:06 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Pavlos+Vougiouklis&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/b6e01c910d434b94/65677596b5961ea5423e7235.html', 'total_time_taken': 2.75}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Pavlos Vougiouklis', 'hl': 'en'}, 'profiles': [{'name': 'Pavlos Vougiouklis', 'link': 'https://scholar.google.com/citations?hl=en&user=9J7YeR0AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=9J7YeR0AAAAJ&engine=google_scholar_author&hl=en', 'author_id': '9J7YeR0AAAAJ', 'affiliations': 'Huawei Technologies', 'email': 'Verified email at huawei.com', 'cited_by': 582, 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=9J7YeR0AAAAJ&citpid=4'}]}
# nome:  Pavlos Vougiouklis
# else  Professor of Machine Learning and Computer Vision, University of Southampton, United Kingdom
# {'search_metadata': {'id': '656775992fe302ed9aedf965', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/ad23b8063c91c3ed/656775992fe302ed9aedf965.json', 'created_at': '2023-11-29 17:32:09 UTC', 'processed_at': '2023-11-29 17:32:09 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Jonathon+Hare&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/ad23b8063c91c3ed/656775992fe302ed9aedf965.html', 'total_time_taken': 0.72}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Jonathon Hare', 'hl': 'en'}, 'profiles': [{'name': 'Jon Hare', 'link': 'https://scholar.google.com/citations?hl=en&user=d_HvmVsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=d_HvmVsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'd_HvmVsAAAAJ', 'affiliations': 'NOAA Fisheries, Northeast Fisheries Science Center', 'email': 'Verified email at noaa.gov', 'cited_by': 12303, 'interests': [{'title': 'oceanography', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aoceanography', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:oceanography'}, {'title': 'fisheries', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Afisheries', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:fisheries'}, {'title': 'climate change', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aclimate_change', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:climate_change'}, {'title': 'management', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amanagement', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:management'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=d_HvmVsAAAAJ&citpid=3'}, {'name': 'Jonathon Hare', 'link': 'https://scholar.google.com/citations?hl=en&user=UFeON5oAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=UFeON5oAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'UFeON5oAAAAJ', 'affiliations': 'Professor of Machine Learning and Computer Vision, University of Southampton, United …', 'email': 'Verified email at ecs.soton.ac.uk', 'cited_by': 4510, 'interests': [{'title': 'Deep Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adeep_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:deep_learning'}, {'title': 'Representation Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Arepresentation_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:representation_learning'}, {'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}, {'title': 'Computer Vision', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acomputer_vision', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:computer_vision'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=UFeON5oAAAAJ&citpid=1'}, {'name': "Jonathan O'Hare", 'link': 'https://scholar.google.com/citations?hl=en&user=voxlV_AAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=voxlV_AAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'voxlV_AAAAAJ', 'affiliations': '3M Company', 'email': 'Verified email at mmm.com', 'cited_by': ...
# else  Professore, Università di Udine
# {'search_metadata': {'id': '6567759ac504e9e78cdf2502', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/7625ba8606f455a7/6567759ac504e9e78cdf2502.json', 'created_at': '2023-11-29 17:32:10 UTC', 'processed_at': '2023-11-29 17:32:10 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Carlo+Alberto+Beltrami&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/7625ba8606f455a7/6567759ac504e9e78cdf2502.html', 'total_time_taken': 1.46}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Carlo Alberto Beltrami', 'hl': 'en'}, 'profiles': [{'name': 'Carlo Alberto Beltrami', 'link': 'https://scholar.google.com/citations?hl=en&user=EZrMWWMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=EZrMWWMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'EZrMWWMAAAAJ', 'affiliations': 'Professore, Università di Udine', 'email': 'Verified email at uniud.it', 'cited_by': 18396, 'interests': [{'title': 'cellule staminali', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acellule_staminali', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:cellule_staminali'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=EZrMWWMAAAAJ&citpid=1'}]}
# nome:  Carlo Alberto Beltrami
# else  University of Southampton
# {'search_metadata': {'id': '6567759c2bc7d8cdf2b7d7c2', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/58ed26ceb61da337/6567759c2bc7d8cdf2b7d7c2.json', 'created_at': '2023-11-29 17:32:12 UTC', 'processed_at': '2023-11-29 17:32:12 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Richard+Gomer&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/58ed26ceb61da337/6567759c2bc7d8cdf2b7d7c2.html', 'total_time_taken': 1.01}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Richard Gomer', 'hl': 'en'}, 'profiles': [{'name': 'Richard Gomer', 'link': 'https://scholar.google.com/citations?hl=en&user=z1YBrC4AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=z1YBrC4AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'z1YBrC4AAAAJ', 'affiliations': 'Professor of Biology, Texas A&M University', 'email': 'Verified email at tamu.edu', 'cited_by': 10330, 'interests': [{'title': 'fibrosis', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Afibrosis', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:fibrosis'}, {'title': 'Dictyostelium', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adictyostelium', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:dictyostelium'}, {'title': 'cell density sensing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acell_density_sensing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:cell_density_sensing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=z1YBrC4AAAAJ&citpid=1'}, {'name': 'Richard Gomer', 'link': 'https://scholar.google.com/citations?hl=en&user=5ZTLglQAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=5ZTLglQAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '5ZTLglQAAAAJ', 'affiliations': 'University of Southampton', 'email': 'Verified email at soton.ac.uk', 'cited_by': 282, 'interests': [{'title': 'privacy', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprivacy', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:privacy'}, {'title': 'consent', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aconsent', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:consent'}, {'title': 'interaction', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainteraction', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:interaction'}, {'title': 'hci', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahci', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:hci'}, {'title': 'web science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:web_science'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=5ZTLglQAAAAJ&citpid=2'}]}
# nome:  Richard Gomer
# else  Tenured Researcher, CWI Amsterdam
# {'search_metadata': {'id': '6567759e0ead413cd59d3424', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/1b68c469d8b02f0d/6567759e0ead413cd59d3424.json', 'created_at': '2023-11-29 17:32:14 UTC', 'processed_at': '2023-11-29 17:32:14 UTC', 'google_scholar_profiles_url': 'https://scholar.google.com/citations?mauthors=Davide+Ceolin&view_op=search_authors&hl=en', 'raw_html_file': 'https://serpapi.com/searches/1b68c469d8b02f0d/6567759e0ead413cd59d3424.html', 'total_time_taken': 1.63}, 'search_parameters': {'engine': 'google_scholar_profiles', 'mauthors': 'Davide Ceolin', 'hl': 'en'}, 'profiles': [{'name': 'Davide Ceolin', 'link': 'https://scholar.google.com/citations?hl=en&user=y8Jy518AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=y8Jy518AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'y8Jy518AAAAJ', 'affiliations': 'Tenured Researcher, CWI Amsterdam', 'email': 'Verified email at cwi.nl', 'cited_by': 498, 'interests': [{'title': 'Information Quality', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_quality', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_quality'}, {'title': 'Trust', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atrust', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:trust'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Probabilistic Logic', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprobabilistic_logic', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:probabilistic_logic'}, {'title': 'Provenance', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprovenance', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:provenance'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}]}
# nome:  Davide Ceolin
# già presente in nodes
# sta sovrascrivendo con:  name                                                Davide Ceolin
# affiliations                    Tenured Researcher, CWI Amsterdam
# author_id                                            y8Jy518AAAAJ
# cited_by                                                      498
# interests       Information Quality, Trust, Semantic Web, Prob...
# Name: 0, dtype: object

# %% [markdown]
# ## Main es 2

# %%
##df_Coauthors = pd.DataFrame(columns=['name','affiliations','author_id','cited_by','interests'])
nodes = pd.read_csv(r'Data/nodes.csv')
for autore in nodes["author_id"]:
    get_profile_coauthors(apikey,autore,nodes)

# %% [markdown]
# # Parte 3
# Usare il due dataset per creare grafico indiretto:
# a. Generare un grafo indiretto che ne rappresenta le informazioni contenute.
# Salvare (serializzare) il grafo in locale nella cartella /graphs .
# b. Visualizzare il grafo prodotto colorando i nodi a seconda del loro grado con le
# seguenti colorazioni: grigio per nodi con grado uguale a 1, blu per nodi con grado compreso tra 2 e 10, viola per nodi con grado compreso tra 11 e 20, giallo per nodi con grado maggiore di 20. Inoltre, per ciascun nodo visualizzare il nome dell’autore. Salvare la visualizzazione nella cartella /visualizations.

# %%
import matplotlib.pyplot as plt
import networkx as nx
# Creazione di un grafo vuoto
G = nx.Graph()
# Leggi i CSV
nodi = pd.read_csv('Data/nodes.csv')
edges = pd.read_csv('Data/edges.csv')


# Aggiungi i nodi al grafo
nodes = nodi['name'].tolist()
G.add_nodes_from(nodes)

# Aggiungi gli archi al grafo
edges = edges[['author1', 'author2']].values.tolist()
G.add_edges_from(edges)

'''
grigio per nodi con grado uguale a 1, blu per nodi con grado compreso tra 2 e 10, viola per nodi con grado compreso tra 11 e 20, giallo per nodi con grado maggiore di 20
'''
#calcolo dela deegree
degrees = dict(G.degree())
print(degrees)
colori_specifici={}
for nodo, grado in degrees.items():
    if grado == 1:
        colori_specifici[nodo] = 'gray'
        #colore grigio
    elif grado in range(2, 10):
        colori_specifici[nodo] = 'blue'
        #colore blu
    elif grado in range(11, 20):
        colori_specifici[nodo] = 'purple'
    elif grado:
        colori_specifici[nodo] = 'yellow'
        #colore gioallo

# Aggiungi un titolo al grafo
plt.title("Grafo INDIRETTO Autori-Coautori ")

print(colori_specifici)
# 1.3 | Visualizzo il grafo
nx.draw(G, with_labels=True, node_color = colori_specifici.values())
# Out:
# {'David La Barbera': 9, 'Michael Soprano': 18, 'Kevin Roitero': 20, 'Stefano Mizzaro': 20, 'Damiano Spina': 21, 'Gianluca Demartini': 21, 'Eddy Maddalena': 21, 'Vincenzo Della Mea': 5, 'Davide Ceolin': 4, 'Tim Draws': 3, 'Joel Mackenzie': 1, 'Beatrice Portelli': 2, 'Giuseppe Serra': 1, 'Shaoyang Fan': 2, 'Giuseppe Primiero': 1, 'Jan Wielemaker': 1, 'Alessandro Checco': 4, 'Afshin Rahimi': 1, 'Andrea Brunello': 2, 'Tetsuya Sakai': 1, 'Mihai Horia Popescu': 1, 'Falk Scholer': 4, 'J. Shane Culpepper': 1, 'Yunke Qu': 1, 'Mark Sanderson': 3, 'Rishabh Mehrotra': 1, 'Mounia Lalmas': 1, 'Luca Vassena': 1, 'Luca Di Gaspero': 1, 'Carlo Tasso': 1, 'Paolo Coppola': 1, 'Omar Alonso': 1, 'Elena Nazzi': 1, 'Fabio Crestani': 1, 'Claudio Carpineto': 1, 'Marco Pavan': 1, 'Andrew Turpin': 2, 'Julio Gonzalo': 1, 'Lawrence Cavedon': 1, 'Johanne R. Trippas': 1, 'Jorge Carrillo-de-Albornoz': 1, 'Maarten de Rijke': 1, 'Arkaitz Zubiaga': 1, 'Hideo Joho': 1, 'Edgar Meij': 1, 'Flora Salim': 1, 'W. Bruce Croft': 1, 'Víctor Fresno': 1, 'Raquel Martinez': 1, 'Yongli Ren': 1, 'Ryen W. White': 1, 'Philippe Cudre-Mauroux': 1, 'Djellel Difallah': 1, 'Ujwal Gadiraju': 2, 'Tereza Iofciu': 1, 'Michele Catasta': 1, 'Lei Han': 2, 'Shazia Sadiq': 1, 'Peter A Bath': 1, 'Dr. Wasim Ahmed, PhD': 1, 'Karl Aberer': 1, 'Alberto Tonon': 1, 'Laura Sbaffi': 1, 'Elena Simperl': 1, 'Cristina Sarasua': 1, 'Luis-Daniel Ibáñez': 1, 'Marco Basaldella': 1, 'Mattia Zeni': 1, "Dante Degl'Innocenti": 1, 'Pavlos Vougiouklis': 1, 'Carlo Alberto Beltrami': 1, 'Richard Gomer': 1, 'Giorgio Brajnik': 1, 'Wolfgang Nejdl': 1, 'Claudiu S. Firan': 1, 'Jonathon Hare': 1}
# {'David La Barbera': 'blue', 'Michael Soprano': 'purple', 'Kevin Roitero': 'yellow', 'Stefano Mizzaro': 'yellow', 'Damiano Spina': 'yellow', 'Gianluca Demartini': 'yellow', 'Eddy Maddalena': 'yellow', 'Vincenzo Della Mea': 'blue', 'Davide Ceolin': 'blue', 'Tim Draws': 'blue', 'Joel Mackenzie': 'gray', 'Beatrice Portelli': 'blue', 'Giuseppe Serra': 'gray', 'Shaoyang Fan': 'blue', 'Giuseppe Primiero': 'gray', 'Jan Wielemaker': 'gray', 'Alessandro Checco': 'blue', 'Afshin Rahimi': 'gray', 'Andrea Brunello': 'blue', 'Tetsuya Sakai': 'gray', 'Mihai Horia Popescu': 'gray', 'Falk Scholer': 'blue', 'J. Shane Culpepper': 'gray', 'Yunke Qu': 'gray', 'Mark Sanderson': 'blue', 'Rishabh Mehrotra': 'gray', 'Mounia Lalmas': 'gray', 'Luca Vassena': 'gray', 'Luca Di Gaspero': 'gray', 'Carlo Tasso': 'gray', 'Paolo Coppola': 'gray', 'Omar Alonso': 'gray', 'Elena Nazzi': 'gray', 'Fabio Crestani': 'gray', 'Claudio Carpineto': 'gray', 'Marco Pavan': 'gray', 'Andrew Turpin': 'blue', 'Julio Gonzalo': 'gray', 'Lawrence Cavedon': 'gray', 'Johanne R. Trippas': 'gray', 'Jorge Carrillo-de-Albornoz': 'gray', 'Maarten de Rijke': 'gray', 'Arkaitz Zubiaga': 'gray', 'Hideo Joho': 'gray', 'Edgar Meij': 'gray', 'Flora Salim': 'gray', 'W. Bruce Croft': 'gray', 'Víctor Fresno': 'gray', 'Raquel Martinez': 'gray', 'Yongli Ren': 'gray', 'Ryen W. White': 'gray', 'Philippe Cudre-Mauroux': 'gray', 'Djellel Difallah': 'gray', 'Ujwal Gadiraju': 'blue', 'Tereza Iofciu': 'gray', 'Michele Catasta': 'gray', 'Lei Han': 'blue', 'Shazia Sadiq': 'gray', 'Peter A Bath': 'gray', 'Dr. Wasim Ahmed, PhD': 'gray', 'Karl Aberer': 'gray', 'Alberto Tonon': 'gray', 'Laura Sbaffi': 'gray', 'Elena Simperl': 'gray', 'Cristina Sarasua': 'gray', 'Luis-Daniel Ibáñez': 'gray', 'Marco Basaldella': 'gray', 'Mattia Zeni': 'gray', "Dante Degl'Innocenti": 'gray', 'Pavlos Vougiouklis': 'gray', 'Carlo Alberto Beltrami': 'gray', 'Richard Gomer': 'gray', 'Giorgio Brajnik': 'gray', 'Wolfgang Nejdl': 'gray', 'Claudiu S. Firan': 'gray', 'Jonathon Hare': 'gray'}

# %%
import matplotlib.pyplot as plt
import networkx as nx
# Creazione di un grafo vuoto
G = nx.Graph()
# Leggi i CSV
nodi = pd.read_csv('Data/nodes.csv')
edges = pd.read_csv('Data/edges.csv')


# Aggiungi i nodi al grafo
nodes = nodi['name'].tolist()
G.add_nodes_from(nodes)

# Aggiungi gli archi al grafo
edges = edges[['author1', 'author2']].values.tolist()
G.add_edges_from(edges)

'''
grigio per nodi con grado uguale a 1, blu per nodi con grado compreso tra 2 e 10, viola per nodi con grado compreso tra 11 e 20, giallo per nodi con grado maggiore di 20
'''
#calcolo dela deegree
degrees = dict(G.degree())
print(degrees)
colori_specifici={}
for nodo, grado in degrees.items():
    if grado == 1:
        colori_specifici[nodo] = 'gray'
        #colore grigio
    elif grado in range(2, 10):
        colori_specifici[nodo] = 'blue'
        #colore blu
    elif grado in range(11, 20):
        colori_specifici[nodo] = 'purple'
    elif grado:
        colori_specifici[nodo] = 'yellow'
        #colore gioallo

# Aggiungi un titolo al grafo
plt.title("Grafo INDIRETTO Autori-Coautori ")

print(colori_specifici)
# 1.3 | Visualizzo il grafo
nx.draw(G, with_labels=True, node_color = colori_specifici.values())
# Out:
# {'David La Barbera': 9, 'Michael Soprano': 1, 'Kevin Roitero': 1, 'Stefano Mizzaro': 1, 'Damiano Spina': 1, 'Gianluca Demartini': 1, 'Eddy Maddalena': 0, 'Vincenzo Della Mea': 1, 'Davide Ceolin': 1, 'Tim Draws': 1, 'Joel Mackenzie': 1}
# {'David La Barbera': 'blue', 'Michael Soprano': 'gray', 'Kevin Roitero': 'gray', 'Stefano Mizzaro': 'gray', 'Damiano Spina': 'gray', 'Gianluca Demartini': 'gray', 'Vincenzo Della Mea': 'gray', 'Davide Ceolin': 'gray', 'Tim Draws': 'gray', 'Joel Mackenzie': 'gray'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 43
#      41 print(colori_specifici)
#      42 # 1.3 | Visualizzo il grafo
# ---> 43 nx.draw(G, with_labels=True, node_color = colori_specifici.values())
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:303, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     300 if pos is None:
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
# --> 303 draw_networkx_nodes(G, pos, **node_kwds)
#     304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:433, in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     430     node_color = apply_alpha(node_color, alpha, nodelist, cmap, vmin, vmax)
#     431     alpha = None
# --> 433 node_collection = ax.scatter(
#     434     xy[:, 0],
#     435     xy[:, 1],
#     436     s=node_size,
#     437     c=node_color,
#     438     marker=node_shape,
#     439     cmap=cmap,
#     440     vmin=vmin,
#     441     vmax=vmax,
#     442     alpha=alpha,
#     443     linewidths=linewidths,
#     444     edgecolors=edgecolors,
#     445     label=label,
#     446 )
#     447 ax.tick_params(
#     448     axis="both",
#     449     which="both",
#    (...)
#     453     labelleft=False,
#     454 )
#     456 if margins is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4596, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4593 if edgecolors is None:
#    4594     orig_edgecolor = kwargs.get('edgecolor', None)
#    4595 c, colors, edgecolors = \
# -> 4596     self._parse_scatter_color_args(
#    4597         c, edgecolors, kwargs, x.size,
#    4598         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4600 if plotnonfinite and colors is None:
#    4601     c = np.ma.masked_invalid(c)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4449, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4445     else:
#    4446         if len(colors) not in (0, 1, xsize):
#    4447             # NB: remember that a single color is also acceptable.
#    4448             # Besides *colors* will be an empty array if c == 'none'.
# -> 4449             raise invalid_shape_exception(len(colors), xsize)
#    4450 else:
#    4451     colors = None  # use cmap, norm after collection is created
#
# ValueError: 'c' argument has 10 elements, which is inconsistent with 'x' and 'y' with size 11.

# %%
#ES 2
def draw(G, pos, measures, title):
    nodes = nx.draw_networkx_nodes(G, pos, node_size = 150, cmap = plt.cm.plasma,
                                   node_color  = list(measures.values()),
                                   nodelist = measures.keys()
                                   )
    edges = nx.draw_networkx_edges(G, pos)
    plt.title(title)
    plt.colorbar(nodes)
    plt.axis('off')
    plt.show()
    # 2.1 | Genero grafo con proprietà piccolo mondo
G = nx.watts_strogatz_graph(15, 4, .3)

# 2.2 | Centralità di grado per tutti i nodi
degrees = dict(G.degree())
df = pd.DataFrame(list(degrees.items()), columns=['node', 'degree'])
print("Centralità di grado:")
display(df)


# 2.3 | Calcolo le altre priprietà richieste
num_edges = G.number_of_edges()
# Grado medio 
avg_degree = sum(degrees.values()) / G.number_of_nodes()
# Densità del grafo
density = nx.density(G)
# Nodo più connesso
max_degree_node = max(degrees, key=degrees.get)

print(f"Number of edges: {num_edges}")
print(f"Average degree: {avg_degree:.2f}")
print(f"Density: {density:.2f}")
print(f"Most connected node: {max_degree_node}")
# 2.4 | Visualizzo usando lo spring layout
draw(
    G,
    nx.spring_layout(G),
    nx.degree_centrality(G),
    title = "Visualizzazione della rete Piccolo Mondo generata"
      )
# Out:
# {'David La Barbera': 9, 'Michael Soprano': 1, 'Kevin Roitero': 1, 'Stefano Mizzaro': 1, 'Damiano Spina': 1, 'Gianluca Demartini': 1, 'Eddy Maddalena': 0, 'Vincenzo Della Mea': 1, 'Davide Ceolin': 1, 'Tim Draws': 1, 'Joel Mackenzie': 1}
# {'David La Barbera': 'blue', 'Michael Soprano': 'gray', 'Kevin Roitero': 'gray', 'Stefano Mizzaro': 'gray', 'Damiano Spina': 'gray', 'Gianluca Demartini': 'gray', 'Vincenzo Della Mea': 'gray', 'Davide Ceolin': 'gray', 'Tim Draws': 'gray', 'Joel Mackenzie': 'gray'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 42
#      40 print(colori_specifici)
#      41 # 1.3 | Visualizzo il grafo
# ---> 42 nx.draw(G, with_labels=True, node_color = colori_specifici.values())
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:303, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     300 if pos is None:
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
# --> 303 draw_networkx_nodes(G, pos, **node_kwds)
#     304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:433, in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     430     node_color = apply_alpha(node_color, alpha, nodelist, cmap, vmin, vmax)
#     431     alpha = None
# --> 433 node_collection = ax.scatter(
#     434     xy[:, 0],
#     435     xy[:, 1],
#     436     s=node_size,
#     437     c=node_color,
#     438     marker=node_shape,
#     439     cmap=cmap,
#     440     vmin=vmin,
#     441     vmax=vmax,
#     442     alpha=alpha,
#     443     linewidths=linewidths,
#     444     edgecolors=edgecolors,
#     445     label=label,
#     446 )
#     447 ax.tick_params(
#     448     axis="both",
#     449     which="both",
#    (...)
#     453     labelleft=False,
#     454 )
#     456 if margins is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4596, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4593 if edgecolors is None:
#    4594     orig_edgecolor = kwargs.get('edgecolor', None)
#    4595 c, colors, edgecolors = \
# -> 4596     self._parse_scatter_color_args(
#    4597         c, edgecolors, kwargs, x.size,
#    4598         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4600 if plotnonfinite and colors is None:
#    4601     c = np.ma.masked_invalid(c)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4449, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4445     else:
#    4446         if len(colors) not in (0, 1, xsize):
#    4447             # NB: remember that a single color is also acceptable.
#    4448             # Besides *colors* will be an empty array if c == 'none'.
# -> 4449             raise invalid_shape_exception(len(colors), xsize)
#    4450 else:
#    4451     colors = None  # use cmap, norm after collection is created
#
# ValueError: 'c' argument has 10 elements, which is inconsistent with 'x' and 'y' with size 11.

# %%
#usare la stessa funzione iniziale, quando passi l'id del autore e restituisce tutti i dati, di cui recuprei i coautori, crei direttamente il datframe quello dei nodi, ciclano n-volte( che saranno il numero di coaurori, e crei una riga insrendo l'Id del autore + vicino il coautore.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nodes
#       5 #usare la stessa funzione iniziale, quando passi l'id del autore e restituisce tutti i dati, di cui recuprei i coautori, crei direttamente il datframe quello dei nodi, ciclano n-volte( che saranno il numero di coaurori, e crei una riga insrendo l'Id del autore + vicino il coautore.
#
# NameError: name 'nodes' is not defined
